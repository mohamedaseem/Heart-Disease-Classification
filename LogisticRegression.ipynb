# %% [markdown]
# <b>Import modules</b>

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import jaccard_score
import os
import requests
import colorthief

# %% [markdown]
# <b>To read CSV file</b>

# %%
input = pd.read_csv(r"C:\Users\salim\Desktop\my_codes\heart.csv")

# %% [markdown]
# <b>Classifying data with feature columns</b>

# %%
output_label = input.columns[-1]
input_features = input.columns[:-1]

# %% [markdown]
# <b>Get the first 10 rows</b>

# %%
input.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
# 5              N      0.0       Up             0
# 6              N      0.0       Up             0
# 7              N      0.0       Up             0
# 8              Y      1.5     Flat             1
# 9              N      0.0       Up             0

# %%
input.shape
# Out:
# (918, 12)

# %%
X = input[input_features]
Y = input[[output_label]]

# %% [markdown]
# <b>Input features</b>

# %%
X
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 0      172              N      0.0       Up
# 1      156              N      1.0     Flat
# 2       98              N      0.0       Up
# 3      108              Y      1.5     Flat
# 4      122              N      0.0       Up
# ..     ...            ...      ...      ...
# 913    132              N      1.2     Flat
# 914    141              N      3.4     Flat
# 915    115              Y      1.2     Flat
# 916    174              N      0.0     Flat
# 917    173              N      0.0       Up
#
# [918 rows x 11 columns]

# %% [markdown]
# <b>Output labels</b>

# %%
Y
# Out:
#      HeartDisease
# 0               0
# 1               1
# 2               0
# 3               1
# 4               0
# ..            ...
# 913             1
# 914             1
# 915             1
# 916             1
# 917             0
#
# [918 rows x 1 columns]

# %% [markdown]
# <b>Train-Test Split</b>

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1)

# %%
x_train
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 555   58   M           NAP        150          219          0         ST
# 776   62   F           ASY        150          244          0     Normal
# 369   63   M           ASY        150            0          0     Normal
# 463   51   M           ASY        128            0          0     Normal
# 408   59   M           ASY        110            0          1     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 451   64   M           ASY        144            0          0         ST
# 699   57   M           ASY        110          201          0     Normal
# 523   59   M           ASY        124          160          0     Normal
# 352   56   M           ASY        120            0          0         ST
# 757   50   M           NAP        140          233          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 555    118              Y      0.0     Flat
# 776    154              Y      1.4     Flat
# 369     86              Y      2.0     Flat
# 463    107              N      0.0       Up
# 408     94              N      0.0     Flat
# ..     ...            ...      ...      ...
# 451    122              Y      1.0     Flat
# 699    126              Y      1.5     Flat
# 523    117              Y      1.0     Flat
# 352    100              Y     -1.0     Down
# 757    163              N      0.6     Flat
#
# [826 rows x 11 columns]

# %% [markdown]
# <b>And we apply the get_dummies() function</b>

# %%
processed_x_train = pd.get_dummies(x_train[["Sex", "ChestPainType", "RestingECG", "ExerciseAngina", "ST_Slope"]])

# %% [markdown]
# <b>Combine two Series</b>

# %%
final_x_train = pd.concat([x_train, processed_x_train], axis="columns")

# %%
final_x_train = final_x_train.drop(["Sex", "ChestPainType", "RestingECG", "ExerciseAngina", "ST_Slope"], axis=1)

# %%
final_x_train
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_F  Sex_M  \
# 555   58        150          219          0    118      0.0      0      1
# 776   62        150          244          0    154      1.4      1      0
# 369   63        150            0          0     86      2.0      0      1
# 463   51        128            0          0    107      0.0      0      1
# 408   59        110            0          1     94      0.0      0      1
# ..   ...        ...          ...        ...    ...      ...    ...    ...
# 451   64        144            0          0    122      1.0      0      1
# 699   57        110          201          0    126      1.5      0      1
# 523   59        124          160          0    117      1.0      0      1
# 352   56        120            0          0    100     -1.0      0      1
# 757   50        140          233          0    163      0.6      0      1
#
#      ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 555                  0                  0                  1
# 776                  1                  0                  0
# 369                  1                  0                  0
# 463                  1                  0                  0
# 408                  1                  0                  0
# ..                 ...                ...                ...
# 451                  1                  0                  0
# 699                  1                  0                  0
# 523                  1                  0                  0
# 352                  1                  0                  0
# 757                  0                  0                  1
#
#      ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 555                 0               0                  0              1
# 776                 0               0                  1              0
# 369                 0               0                  1              0
# 463                 0               0                  1              0
# 408                 0               0                  1              0
# ..                ...             ...                ...            ...
# 451                 0               0                  0              1
# 699                 0               0                  1              0
# 523                 0               0                  1              0
# 352                 0               0                  0              1
# 757                 0               0                  1              0
#
#      ExerciseAngina_N  ExerciseAngina_Y  ST_Slope_Down  ST_Slope_Flat  \
# 555                 0                 1              0              1
# 776                 0                 1              0              1
# 369                 0                 1              0              1
# 463                 1                 0              0              0
# 408                 1                 0              0              1
# ..                ...               ...            ...            ...
# 451                 0                 1              0              1
# 699                 0                 1              0              1
# 523                 0                 1              0              1
# 352                 0                 1              1              0
# 757                 1                 0              0              1
#
#      ST_Slope_Up
# 555            0
# 776            0
# 369            0
# 463            1
# 408            0
# ..           ...
# 451            0
# 699            0
# 523            0
# 352            0
# 757            0
#
# [826 rows x 20 columns]

# %% [markdown]
# <b>Standardize features by removing the mean and scaling to unit variance</b>

# %%
final_x_train = preprocessing.StandardScaler().fit(final_x_train).transform(final_x_train)

# %%
final_x_train[0]
# Out:
# array([ 0.47122414,  0.9316057 ,  0.19405592, -0.55590762, -0.73044645,
#        -0.81778728, -0.51283227,  0.51283227, -1.0966616 , -0.47680213,
#         1.88107989, -0.22558942, -0.50529115, -1.24474203,  2.07240725,
#        -1.20761473,  1.20761473, -0.27481054,  1.01218072, -0.8789381 ])

# %%
y_train
# Out:
#      HeartDisease
# 555             1
# 776             1
# 369             1
# 463             0
# 408             1
# ..            ...
# 451             1
# 699             0
# 523             1
# 352             1
# 757             1
#
# [826 rows x 1 columns]

# %% [markdown]
# <b>Model building</b>

# %%
log_reg = LogisticRegression()
log_reg.fit(final_x_train, y_train)
# Out:
# C:\Users\salim\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression()

# %%
log_reg.coef_
# Out:
# array([[ 0.11310861,  0.0377977 , -0.39254646,  0.4730324 , -0.11356114,
#          0.42978858, -0.29223788,  0.29223788,  0.5045942 , -0.33163924,
#         -0.24112025, -0.10459066,  0.03455238, -0.00816015, -0.02535472,
#         -0.23246808,  0.23246808, -0.05978984,  0.60899883, -0.58322223]])

# %%
log_reg.intercept_
# Out:
# array([0.38603602])

# %% [markdown]
# <b>Evaluate model-build on validation set</b>

# %%
processed_x_test = pd.get_dummies(x_test[["Sex", "ChestPainType", "RestingECG", "ExerciseAngina", "ST_Slope"]])
final_x_test = pd.concat([x_test, processed_x_test], axis="columns")
final_x_test = final_x_test.drop(["Sex", "ChestPainType", "RestingECG", "ExerciseAngina", "ST_Slope"], axis=1)

# %%
final_x_test = preprocessing.StandardScaler().fit(final_x_test).transform(final_x_test)
final_x_test
# Out:
# array([[-0.93046106, -0.71991879,  0.1089263 , ..., -0.23973165,
#         -1.14017543,  1.27615494],
#        [ 0.20952271,  0.03846894,  1.36393784, ..., -0.23973165,
#          0.87705802, -0.78360391],
#        [ 0.41679248,  0.54406076, -1.96703263, ..., -0.23973165,
#          0.87705802, -0.78360391],
#        ...,
#        [-1.13773083, -0.71991879,  0.29764984, ...,  4.17133072,
#         -1.14017543, -0.78360391],
#        [-1.03409594, -1.03591368,  0.89212899, ..., -0.23973165,
#          0.87705802, -0.78360391],
#        [ 1.76404602,  1.5552444 ,  0.34483073, ..., -0.23973165,
#         -1.14017543,  1.27615494]])

# %%
final_x_test.shape
# Out:
# (92, 20)

# %%
model_predictions = log_reg.predict(final_x_test)

# %%
jaccard_score(y_test, model_predictions)
# Out:
# 0.8392857142857143
